# %%
# !pip install -q deeppavlov

# %%
# !pip install -q deeppavlov

# %%
pip install deeppavlov
# Out:
# ...
#
# ...

# %%
# !pip install --q deeppavlov

# %%
# !python -m deeppavlov install squad_bert

# %%
from deeppavlov import build_model

model = build_model('squad_bert', download=True)
# Out:
# 2022-11-18 07:45:21.226 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/squad/squad_torch_bert_cased.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# ...

# %%
python -m deeppavlov install squad_torch_bert

# %%
# !python -m deeppavlov install squad_torch_bert

# %%
from deeppavlov import build_model

model = build_model('squad__torch_bert', download=True)

# %%
pip install torch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m deeppavlov interact squad_bert -d

# %%
from deeppavlov import build_model

model = build_model('squad_bert', download=True)
# Out:
# 2022-11-18 07:45:51.371 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/squad/squad_torch_bert_cased.tar.gz download because of matching hashes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25100\2177899434.py in <module>
#       1 from deeppavlov import build_model
#       2
# ----> 3 model = build_model('squad_bert', download=True)
#
# ~\anaconda3\envs\deepPavlov\lib\site-packages\deeppavlov\core\commands\infer.py in build_model(config, mode, load_trained, download)
#      51                             .format(component_config.get('class_name', component_config.get('ref', 'UNKNOWN'))))
#      52
# ---> 53         component = from_params(component_config, mode=mode)
#      54
#      55         if 'id' in component_config:
#
# ...

# %%
pip install torchvision
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deeppavlov import build_model

model = build_model('squad_bert', download=True)
# Out:
# 2022-11-18 17:31:47.279 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/squad/squad_torch_bert_cased.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# ...

# %%
model(['DeepPavlov is a library for NLP and dialog systems.'], ['What is DeepPavlov?'])
# Out:
# [['a library for NLP and dialog systems'], [14], [1.0]]

# %%
model(['With a personal account on GitHub, you can import or create repositorie'], ['What can you do?'])
# Out:
# [['import or create repositorie'], [43], [1.0]]
